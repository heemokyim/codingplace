# %%
import pandas as pds

# %%
data=pds.read_csv('supermarkets.csv')
data=data.set_index('Address')

# %%
data
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
# length of rows
data.shape[0]
# length of columns
data.shape[1]
# Out:
# 6

# %%
data['Continent']=data.shape[0]*['North America']
data
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
data.shape
# Out:
# (6, 7)

# %%
# adding a empty column?
# data[new_column]=numpy.nan
data.shape[0]*['hahaha']
# Out:
# ['hahaha', 'hahaha', 'hahaha', 'hahaha', 'hahaha', 'hahaha']

# %%
data['Continent']=data['Country']+", North America"
data
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees           Continent
# Address
# 3666 21st St             8  USA, North America
# 735 Dolores St          15  USA, North America
# 332 Hill St             25  USA, North America
# 3995 23rd St            10  USA, North America
# 1056 Sanchez St         12  USA, North America
# 551 Alvarado St         20  USA, North America

# %%
# Transpose table
data_t=data.T
data_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
# How to add row?
# 1. add column in transposed
# 2. transpose 1
data_t['My Address']=['My city','My country',10,7,
                     'My shop','My state','My continent']
data_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# ID                          1                   2                   3
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St  \
# ID                          4                   5                   6
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
data=data_t.T
data
# Out:
#                       ID           City             State Country  \
# Address
# 3666 21st St           1  San Francisco          CA 94114     USA
# 735 Dolores St         2  San Francisco          CA 94119     USA
# 332 Hill St            3  San Francisco  California 94114     USA
# 3995 23rd St           4  San Francisco          CA 94114     USA
# 1056 Sanchez St        5  San Francisco        California     USA
# 551 Alvarado St        6  San Francisco          CA 94114     USA
# My Address       My city     My country                10       7
#
#                         Name Employees           Continent
# Address
# 3666 21st St         Madeira         8  USA, North America
# 735 Dolores St   Bready Shop        15  USA, North America
# 332 Hill St      Super River        25  USA, North America
# 3995 23rd St      Ben's Shop        10  USA, North America
# 1056 Sanchez St      Sanchez        12  USA, North America
# 551 Alvarado St   Richvalley        20  USA, North America
# ...

# %%
for each in range(data.shape[0]):
    data['Continent'][each]=each
data
# Out:
#                       ID           City             State Country  \
# Address
# 3666 21st St           1  San Francisco          CA 94114     USA
# 735 Dolores St         2  San Francisco          CA 94119     USA
# 332 Hill St            3  San Francisco  California 94114     USA
# 3995 23rd St           4  San Francisco          CA 94114     USA
# 1056 Sanchez St        5  San Francisco        California     USA
# 551 Alvarado St        6  San Francisco          CA 94114     USA
# My Address       My city     My country                10       7
#
#                         Name Employees Continent
# Address
# 3666 21st St         Madeira         8         0
# 735 Dolores St   Bready Shop        15         1
# 332 Hill St      Super River        25         2
# 3995 23rd St      Ben's Shop        10         3
# 1056 Sanchez St      Sanchez        12         4
# 551 Alvarado St   Richvalley        20         5
# My Address           My shop  My state         6

# %%
data1=pds.read_csv('supermarkets.csv')
data_merge=pds.merge(left=data,right=data1,on="ID")
data_merge
# Out:
#   ID         City_x           State_x Country_x       Name_x Employees_x  \
# 0  1  San Francisco          CA 94114       USA      Madeira           8
# 1  2  San Francisco          CA 94119       USA  Bready Shop          15
# 2  3  San Francisco  California 94114       USA  Super River          25
# 3  4  San Francisco          CA 94114       USA   Ben's Shop          10
# 4  5  San Francisco        California       USA      Sanchez          12
# 5  6  San Francisco          CA 94114       USA   Richvalley          20
#
#   Continent          Address         City_y           State_y Country_y  \
# 0         0     3666 21st St  San Francisco          CA 94114       USA
# 1         1   735 Dolores St  San Francisco          CA 94119       USA
# 2         2      332 Hill St  San Francisco  California 94114       USA
# 3         3     3995 23rd St  San Francisco          CA 94114       USA
# 4         4  1056 Sanchez St  San Francisco        California       USA
# ...
