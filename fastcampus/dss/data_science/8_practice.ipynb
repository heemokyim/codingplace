# %%
from ml_config import *

# %%
mu = 0
std = 1
rv = sp.stats.norm(mu, std)

xx = np.linspace(-5, 5, 100)

plt.plot(xx, rv.pdf(xx))
plt.show()

# %%
x = rv.rvs(1000)
sns.distplot(x)
plt.show()

# %%
X=np.random.rand(3,2)

# %%
X.sum(axis=1)
# Out:
# array([ 1.22926024,  1.19583718,  0.8872149 ])

# %%
X
# Out:
# array([[ 0.96158   ,  0.26768024],
#        [ 0.77051967,  0.42531751],
#        [ 0.33639701,  0.55081789]])

# %%
np.random.rand(1000,1)-0.5
# Out:
# array([[-0.28784465],
#        [-0.23225368],
#        [-0.35869583],
#        [ 0.19145722],
#        [ 0.41711928],
#        [-0.23083981],
#        [ 0.25304556],
#        [-0.15723245],
#        [ 0.38711154],
#        [ 0.08763446],
#        [ 0.26667453],
#        [-0.48031043],
#        [ 0.18368542],
#        [ 0.36785558],
#        [ 0.08732068],
#        [-0.47459539],
#        [-0.39107434],
#        [ 0.01874956],
#        [ 0.46121069],
#        [-0.07377788],
#        [-0.15730427],
#        [-0.08318954],
#        [-0.3467556 ],
#        [-0.10689553],
#        [ 0.23216149],
#        [-0.35675258],
#        [-0.30083809],
#        [ 0.40808891],
#        [-0.29841739],
#        [ 0.25059732],
#        [-0.20385901],
#        [-0.07846812],
#        [ 0.25720851],
#        [-0.02512508],
#        [-0.03556765],
#        [ 0.11339224],
#        [-0.41261437],
#        [-0.38928673],
#        [-0.03342428],
#        [-0.08036927],
#        [-0.02698151],
# ...

# %%
np.random.rand(10)
# Out:
# array([ 0.8915388 ,  0.45164996,  0.24118526,  0.21368809,  0.02067839,
#         0.43737575,  0.43431105,  0.64539534,  0.76989579,  0.26903089])

# %%
np.random.randn(10)
# Out:
# array([ 0.47888391, -0.73722272,  0.32971701,  0.70861311, -0.5341777 ,
#        -1.7451282 ,  0.70667598,  0.13684803, -1.31154491,  0.04118847])
