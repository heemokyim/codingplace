# %%
from custom_ml import *

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target

# %%
GaussianNB
# Out:
# sklearn.naive_bayes.GaussianNB

# %%
a, b = cls_conf(X,y,GaussianNB(),0.5)

# %%
a
# Out:
# array([[21,  0,  0],
#        [ 0, 30,  0],
#        [ 0,  4, 20]], dtype=int64)

# %%
print(b)
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        21
#           1       0.88      1.00      0.94        30
#           2       1.00      0.83      0.91        24
#
# avg / total       0.95      0.95      0.95        75

# %%
a, b = cls_conf(X,y,LinearDiscriminantAnalysis(n_components=3, 
                                 solver="svd", store_covariance=True),0.5)

# %%
a
# Out:
# array([[21,  0,  0],
#        [ 0, 29,  1],
#        [ 0,  2, 22]], dtype=int64)

# %%
print(b)
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        21
#           1       0.94      0.97      0.95        30
#           2       0.96      0.92      0.94        24
#
# avg / total       0.96      0.96      0.96        75

# %%
multi_roc(X,y,GaussianNB(),0.5)

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=10000, weights=[0.9, 0.1], random_state=1)
bin_roc(X,y,LogisticRegression(),0.5)
