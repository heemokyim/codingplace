# %%
from custom_ml import *

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
X = iris.data
y = iris.target

# %%
cls, conf = cls_conf(X,y,GaussianNB(),0.5)

# %%
cls
# Out:
# array([[21,  0,  0],
#        [ 0, 30,  0],
#        [ 0,  4, 20]], dtype=int64)

# %%
print(conf)
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        21
#           1       0.88      1.00      0.94        30
#           2       1.00      0.83      0.91        24
#
# avg / total       0.95      0.95      0.95        75

# %%
multi_roc(X,y,GaussianNB(),0.5)
