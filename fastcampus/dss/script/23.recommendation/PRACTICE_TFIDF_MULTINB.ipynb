# %%
import pickle
import pandas as pd
import numpy as np
load_model = pickle.load(open('classification.plk', 'rb'))
article = pd.read_pickle(open('article_2016-06-01.plk', 'rb'))

# %%
article
# Out:
#         newsid  oid    newspaper  \
# 0      3689326    8        머니투데이
# 1      8444786    1         연합뉴스
# 2      3556076   18         이데일리
# 3      8444772    1         연합뉴스
# 4      8444770    1         연합뉴스
# 5      8444764    1         연합뉴스
# 6      2320347   28          한겨레
# 7      8444756    1         연합뉴스
# 8      2703739   32         경향신문
# 9      2703736   32         경향신문
# 10    10323768   56       KBS 뉴스
# 11     3061140   22         세계일보
# 12     3061138   22         세계일보
# 13     3180068   23         조선일보
# 14    10323765   56       KBS 뉴스
# 15     8444721    1         연합뉴스
# 16     7265479    3          뉴시스
# 17      146149  469         한국일보
# 18     8444718    1         연합뉴스
# 19    10323759   56       KBS 뉴스
# 20     8444716    1         연합뉴스
# 21     2320337   28          한겨레
# 22     2837265   11         서울경제
# 23    10323750   56       KBS 뉴스
# 24      120439  437         JTBC
# 25      120438  437         JTBC
# 26      120437  437         JTBC
# 27     8444684    1         연합뉴스
# 28      120436  437         JTBC
# 29      415002   55       SBS 뉴스
# ...        ...  ...          ...
# 2297   2086510  421          뉴스1
# 2298   2097441   92  ZDNet Korea
# 2299   2097438   92  ZDNet Korea
# 2300   2097437   92  ZDNet Korea
# 2301   2086489  421          뉴스1
# 2302   2040116  138       디지털데일리
# 2303   3758065  277        아시아경제
# 2304    414639   55       SBS 뉴스
# 2305   3758050  277        아시아경제
# 2306   2097436   92  ZDNet Korea
# 2307   3602954   15         한국경제
# 2308   8442038    1         연합뉴스
# 2309   7263109    3          뉴시스
# 2310   2484859   30         전자신문
# 2311   3688680    8        머니투데이
# 2312   3741398    9         매일경제
# 2313   3741392    9         매일경제
# 2314   3741391    9         매일경제
# 2315   3741390    9         매일경제
# 2316   3741389    9         매일경제
# 2317   3555247   18         이데일리
# 2318    904356    5         국민일보
# 2319    850121   52          YTN
# 2320    850063   52          YTN
# 2321   2724043   81         서울신문
# 2322   2976863   20         동아일보
# 2323   2976847   20         동아일보
# 2324   3179706   23         조선일보
# 2325   2976797   20         동아일보
# 2326   2620983   25         중앙일보
#
#                                                   title  \
# 0                       美 '北 주요자금세탁우려대상국' 지정…'돈줄' 차단 강화
# 1                    美재무부, 북한 '주요 자금세탁 우려 대상국' 첫 지정(3보)
# 2                     '냉정'과 '대화' 강조한 시진핑…北뿐 아니라 한미일도 겨냥
# 3                              北, '200일 전투' 평양시 군중대회 개최
# 4      시진핑, 北리수용에 &quot;냉정·자제…지역 평화·안정 수호해야&quot;(종합2보)
# 5                      美재무부, 북한 '주요 자금세탁 우려 대상국' 지정(2보)
# 6                           시진핑, 리수용 만나 “북-중 협력 고도로 중시”
# 7                  시진핑-김정은 '관계복원' 이구동성…'북핵접점'은 못찾은듯(종합)
# 8          김무성, 측근 의원들과 만나 &quot;(청와대와) 소통 잘 안 됐다&quot;
# 9                          ‘군피아’ 탓…장병들 ‘30년 전 구형’ 침낭 쓴다
# 10                             조국 위해 '펜' 대신 '총'…학도병 추모식
# 11                              시진핑과 면담 성공… 대북제재 돌파구 여나
# 12                          북·중 관계개선 첫발 내디뎠지만… 문제는 '북핵'
# 13                   김무성 &quot;대표때 朴대통령과 얘기 한번 못해&quot;
# 14                         北, 4월 SLBM 영상 공개…무수단 실패 만회용?
# 15                   김무성 최경환, 나란히 '식사 정치'…재개 기지개 켜나(종합)
# 16                             北 리수용이 시진핑에게 어떤 메시지 전달했나
# 17                               정부, 시진핑 대북 메시지에 안도 분위기
# 18                   北中 대화시동, 비핵화엔 이견…한미일 '비핵화 압박' 한목소리
# 19                          "대북 공조·경제 협력 '아프리카 교두보' 마련"
# 20                    원구성 협상 교착, 3당 세비반납 신경전으로 불똥(종합2보)
# 21                   김정은 친서에 ‘핵문제 성의’ 담았나…북-중 대화국면 ‘촉각’
# 22    &#39;選數&#183;나이&#39; 먼저 따지는 한국 상임위  미국에선 &#39;...
# 23                     [앵커&리포트] 제재 허물 기 나선 北…2013년 도돌이표
# 24                        새누리당 "원구성 타결 전에 복당 없다"…논란은 여전
# 25                      '집권여당 vs 1당' 의장 갈등…원구성 협상 전면 중단
# 26                      무겁고 보온도 안 되는…비리로 덮인 '30년 구형 침낭'
# 27                    시진핑-김정은 '관계복원' 이구동성…'핵갈등' 봉합은 미지수
# 28                       녹음에 담긴 '장교 간 폭행', 당시 상황 어땠나보니…
# 29                             국회 원구성 협상 중단에…'세비 반납' 논쟁
# ...                                                 ...
# 2297                &quot;돌돌 말리는 키보드? 처음엔 다들 비웃었죠&quot;
# 2298                             모바일 광고, 동남아서 특히 홀대 당한다
# 2299                         美, 암호화 기기 백도어 의무화 법안 폐기 유력
# 2300                    &#34;아이폰 업그레이드 주기, 2년→3년으로&#34;
# 2301                       소프트뱅크, 알리바바 지분 최소 79억달러어치 매각
# 2302               엑소가 ‘브이한다’는데…네이버, 야심작 브이(V)는 어떤 서비스?
# 2303                          [스페이스]'야누스'…들쭉날쭉 '명암 경계선'
# 2304                           진화하는 3D 프린팅 기술…뼈암 환자 살린다
# 2305                 페북·트위터·유튜브·MS, 유럽에서 '혐오 콘텐츠' 접근 차단
# 2306                               인텔, 컴퓨팅 전 영역 승부수 띄운다
# 2307                네이버 메신저 '라인', 7월 도쿄 증시 상장…미국 상장도 추진
# 2308                       '사이버 인질범' 랜섬웨어 변종 확산…속수무책 형국
# 2309                           이통사·네이버 통합 앱장터 '원스토어' 출범
# 2310                        미 IT기업, EU와 손잡고 `헤이트스피치` 차단
# 2311                      日 소프트뱅크, 中 알리바바 지분 79억달러 매각키로
# 2312       [Health Journal] 빗장 풀린 유전자 지도…보물섬인가, 금단의 땅인가
# 2313  [Cover Story] '황금알' 유전체분석, 한국 이달말 DTC서비스…규제 푼 ...
# 2314                     [Cover Story] 유전체 검사결과 오·남용 우려
# 2315                 [Cover Story] 침 한방울로 탈모·피부노화 진단 OK
# 2316  [Cover Story] &quot;호기심은 어떤 규제로도 못막아…유전정보, 체중·...
# 2317                        '응답했다 대리기사'..카카오 드라이버 사용해보니
# 2318                         24시간 집안·공장 순찰… 친구같은 든든한 로봇
# 2319                           "당신이 대한민국 미래"…격려 공연 '후끈'
# 2308  최신 백신도 무력화…현재로선 예방이 최선    (서울=연합뉴스) 고현실 기자 = 컴...  2016-06-01         5
# 2309  이동통신3사와 네이버 뭉친 토종 앱스토어 등장모바일 게임 특화 서비스로 구글과 애플...  2016-06-01         5
# 2310  구글, 트위터, 마이크로소프트(MS) 등 미국 정보기술(IT) 업체가 유럽연합(EU...  2016-06-01         5
# 2311  [머니투데이 뉴욕=서명훈 특파원] 일본 소프트뱅크가 중국 최대 전자상거래 기업 알리...  2016-06-01         5
# 2312   DNA는 '인간의 설계도이자 부품 정보'라고 불린다. 생김새와 성격, 잘 걸리는 ...  2016-06-01         5
# 2313   이달 30일부터 우리나라에서도 DTC(Direct to Consumer) 서비스가...  2016-06-01         5
# 2314  "당신이 ○○암에 걸릴 확률은 ○○%입니다." 유전체 분석 결과 이런 답변을 들었다...  2016-06-01         5
# 2315   유전체 분석 기업들은 이르면 다음달부터 DTC 관련 서비스를 출시할 예정이다. 대...  2016-06-01         5
# 2316   이종은 유전체기업협의회 회장(디엔에이링크 대표)은 정신없이 바쁜 와중에도 한껏 고...  2016-06-01         5
# 2317  - 가격은 기존 대리운전 업체보다 비싸지만 편의성·안전성↑- 소속 대리운전 기사 만...  2016-06-01         5
# 2318  30일 서울 강남구 인터컨티넨탈 서울 코엑스에서 열린 ‘프랑스 테크 데이 인 코리아...  2016-06-01         5
# 2319  [앵커] 과학기술 50년을 맞아 연구 개발로 눈코 뜰새 없는 과학기술인들을 격려하기...  2016-06-01         5
# 2320  [앵커] 극단적인 흥분과 우울증이 번갈아 나타나는 조울증, 심해지면 자살이나 범죄로...  2016-06-01         5
# 2321  [서울신문]기존 업계보다 기본료 비싸 사업 확장 과정 ‘상생’ 과제로카카오의 O2O...  2016-06-01         5
# 2322  [동아일보][미래산업 먹어치우는 중국]슈퍼 포식자 중국美 로봇업체 인수… 獨기업 눈...  2016-06-01         5
# 2323  [동아일보][2016 동아 국제금융 포럼]‘AI 전문가’ 메네제스 IBM 부사장“A...  2016-06-01         5
# 2324  [정철 카카오 웹 사전 기획자] 책 '검색, 사전을 삼키다' 펴내… 연세대에서 사전...  2016-06-01         5
# 2325  [동아일보]中, 로봇-IoT-바이오 등 M&A; 규모… 올해 5월에 이미 작년 기록...  2016-06-01         5
# 2326  이통 3사, 네이버 손잡고 시장 40% 점유 목표| 양강 구도에 도전장…앱 생태계 ...  2016-06-01         5
#
# [2327 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
TfidfVectorizer(stop_)

# %%
load_model.get_params
# Out:
# <bound method Pipeline.get_params of Pipeline(memory=None,
#      steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#   ...ue,
#         vocabulary=None)), ('clf', MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True))])>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

model1 = Pipeline([
            ('vect', CountVectorizer()), 
            ('mb', MultinomialNB()),
        ])

# %%
models = {}
models["classification"] = load_model
classification_list = ["정치","경제","사회","생활/문화","세계","IT/과학"]
model = models["classification"]

# %%
tmp = '데이터 사이언스'
model.predict_proba(['데이터','사이언스','정치'])[0]
# Out:
# array([ 0.09177323,  0.15858623,  0.02125746,  0.01614871,  0.18202023,
#         0.53021414])

# %%
model.predict_proba(['파이썬'])
# Out:
# array([[ 0.04871354,  0.04759282,  0.0521585 ,  0.03962338,  0.04050889,
#          0.77140286]])
