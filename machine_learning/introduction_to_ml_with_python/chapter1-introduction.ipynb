# %%
from ml_config import *

# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()

# %%
iris_dataset.keys
# Out:
# <function Bunch.keys>

# %%
for each in iris_dataset.keys():
    print(each)
# Out:
# data
# target
# target_names
# DESCR
# feature_names

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    iris_dataset['data'], iris_dataset['target'], random_state=0)

# %%
X_train.shape
# Out:
# (112, 4)

# %%
X_test.shape
# Out:
# (38, 4)

# %%
y_train.shape
# Out:
# (112,)

# %%
y_test.shape
# Out:
# (38,)

# %%
df = pd.DataFrame(X_train, columns = iris_dataset.feature_names)

# %%
pd.plotting.scatter_matrix(df, c=y_train,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E92AFE85F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92AC640B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92AC41828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92AC83AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B20E0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B20E0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92AC98630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B3C3B38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B2F6278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92AD08898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92ADEBF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B027BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B199208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B198908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B33EF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E92B199EB8>]],
#       dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %%
X_new = np.array([[5,2.9,1,0.2]])
X_new.shape
# Out:
# (1, 4)

# %%
predict = knn.predict(X_new)
iris_dataset['target_names'][predict]
# Out:
# array(['setosa'], dtype='<U10')

# %%
y_pred = knn.predict(X_test)

# %%
np.mean(y_pred == y_test)
# Out:
# 0.9736842105263158

# %%
knn.score(X_test, y_test)
# Out:
# 0.9736842105263158
